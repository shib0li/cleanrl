# %%
# docs and experiment results can be found at https://docs.cleanrl.dev/rl-algorithms/dqn/#dqn_ataripy
import os
import random
import time
from dataclasses import dataclass

import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import tyro
from torch.utils.tensorboard import SummaryWriter

from cleanrl_utils.atari_wrappers import (
    ClipRewardEnv,
    EpisodicLifeEnv,
    FireResetEnv,
    MaxAndSkipEnv,
    NoopResetEnv,
)
from cleanrl_utils.buffers import ReplayBuffer


@dataclass
class Args:
    # exp_name: str = os.path.basename(__file__)[: -len(".py")]
    exp_name: str = "dqn_atari"
    """the name of this experiment"""
    seed: int = 1
    """seed of the experiment"""
    torch_deterministic: bool = True
    """if toggled, `torch.backends.cudnn.deterministic=False`"""
    cuda: bool = True
    """if toggled, cuda will be enabled by default"""
    track: bool = False
    """if toggled, this experiment will be tracked with Weights and Biases"""
    wandb_project_name: str = "cleanRL"
    """the wandb's project name"""
    wandb_entity: str = None
    """the entity (team) of wandb's project"""
    capture_video: bool = False
    """whether to capture videos of the agent performances (check out `videos` folder)"""
    save_model: bool = False
    """whether to save model into the `runs/{run_name}` folder"""
    upload_model: bool = False
    """whether to upload the saved model to huggingface"""
    hf_entity: str = ""
    """the user or org name of the model repository from the Hugging Face Hub"""

    # Algorithm specific arguments
    env_id: str = "BreakoutNoFrameskip-v4"
    """the id of the environment"""
    total_timesteps: int = 10000000
    """total timesteps of the experiments"""
    learning_rate: float = 1e-4
    """the learning rate of the optimizer"""
    num_envs: int = 1
    """the number of parallel game environments"""
    buffer_size: int = 1000000
    """the replay memory buffer size"""
    gamma: float = 0.99
    """the discount factor gamma"""
    tau: float = 1.0
    """the target network update rate"""
    target_network_frequency: int = 1000
    """the timesteps it takes to update the target network"""
    batch_size: int = 32
    """the batch size of sample from the reply memory"""
    start_e: float = 1
    """the starting epsilon for exploration"""
    end_e: float = 0.01
    """the ending epsilon for exploration"""
    exploration_fraction: float = 0.10
    """the fraction of `total-timesteps` it takes from start-e to go end-e"""
    learning_starts: int = 80000
    """timestep to start learning"""
    train_frequency: int = 4
    """the frequency of training"""


def make_env(env_id, seed, idx, capture_video, run_name):
    def thunk():
        if capture_video and idx == 0:
            env = gym.make(env_id, render_mode="rgb_array")
            env = gym.wrappers.RecordVideo(env, f"videos/{run_name}")
        else:
            env = gym.make(env_id)
        env = gym.wrappers.RecordEpisodeStatistics(env)

        env = NoopResetEnv(env, noop_max=30)
        env = MaxAndSkipEnv(env, skip=4)
        env = EpisodicLifeEnv(env)
        if "FIRE" in env.unwrapped.get_action_meanings():
            env = FireResetEnv(env)
        env = ClipRewardEnv(env)
        env = gym.wrappers.ResizeObservation(env, (84, 84))
        env = gym.wrappers.GrayScaleObservation(env)
        env = gym.wrappers.FrameStack(env, 4)

        env.action_space.seed(seed)
        return env

    return thunk


# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(4, 32, 8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, 4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, 3, stride=1),
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(3136, 512),
            nn.ReLU(),
            nn.Linear(512, env.single_action_space.n),
        )

    def forward(self, x):
        return self.network(x / 255.0)


def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope = (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)


if __name__ == "__main__":
    # args = tyro.cli(Args)
    # args = tyro.cli(Args, args=["--env-id", "BreakoutNoFrameskip-v4", "--capture_video"])
    args = tyro.cli(Args, args=["--env-id", "PongNoFrameskip-v4"])
    
    assert args.num_envs == 1, "vectorized envs are not supported at the moment"
    run_name = f"{args.env_id}__{args.exp_name}__{args.seed}__{int(time.time())}"
    if args.track:
        import wandb

        wandb.init(
            project=args.wandb_project_name,
            entity=args.wandb_entity,
            sync_tensorboard=True,
            config=vars(args),
            name=run_name,
            monitor_gym=True,
            save_code=True,
        )
    writer = SummaryWriter(f"runs/{run_name}")
    writer.add_text(
        "hyperparameters",
        "|param|value|\n|-|-|\n%s" % ("\n".join([f"|{key}|{value}|" for key, value in vars(args).items()])),
    )

    # TRY NOT TO MODIFY: seeding
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.backends.cudnn.deterministic = args.torch_deterministic

    device = torch.device("cuda" if torch.cuda.is_available() and args.cuda else "cpu")

    # env setup
    envs = gym.vector.SyncVectorEnv(
        [make_env(args.env_id, args.seed + i, i, args.capture_video, run_name) for i in range(args.num_envs)]
    )
    assert isinstance(envs.single_action_space, gym.spaces.Discrete), "only discrete action space is supported"

    q_network = QNetwork(envs).to(device)
    optimizer = optim.Adam(q_network.parameters(), lr=args.learning_rate)
    target_network = QNetwork(envs).to(device)
    target_network.load_state_dict(q_network.state_dict())

    rb = ReplayBuffer(
        args.buffer_size,
        envs.single_observation_space,
        envs.single_action_space,
        device,
        optimize_memory_usage=True,
        handle_timeout_termination=False,
    )
    start_time = time.time()

    # TRY NOT TO MODIFY: start the game
    obs, _ = envs.reset(seed=args.seed)
    for global_step in range(args.total_timesteps):
        # ALGO LOGIC: put action logic here
        epsilon = linear_schedule(args.start_e, args.end_e, args.exploration_fraction * args.total_timesteps, global_step)
        if random.random() < epsilon:
            actions = np.array([envs.single_action_space.sample() for _ in range(envs.num_envs)])
        else:
            q_values = q_network(torch.Tensor(obs).to(device))
            actions = torch.argmax(q_values, dim=1).cpu().numpy()

        # TRY NOT TO MODIFY: execute the game and log data.
        next_obs, rewards, terminations, truncations, infos = envs.step(actions)

        # TRY NOT TO MODIFY: record rewards for plotting purposes
        if "final_info" in infos:
            for info in infos["final_info"]:
                if info and "episode" in info:
                    print(f"global_step={global_step}, episodic_return={info['episode']['r']}")
                    writer.add_scalar("charts/episodic_return", info["episode"]["r"], global_step)
                    writer.add_scalar("charts/episodic_length", info["episode"]["l"], global_step)

        # TRY NOT TO MODIFY: save data to reply buffer; handle `final_observation`
        real_next_obs = next_obs.copy()
        for idx, trunc in enumerate(truncations):
            if trunc:
                real_next_obs[idx] = infos["final_observation"][idx]
        rb.add(obs, real_next_obs, actions, rewards, terminations, infos)

        # TRY NOT TO MODIFY: CRUCIAL step easy to overlook
        obs = next_obs

        # ALGO LOGIC: training.
        if global_step > args.learning_starts:
            if global_step % args.train_frequency == 0:
                data = rb.sample(args.batch_size)
                with torch.no_grad():
                    target_max, _ = target_network(data.next_observations).max(dim=1)
                    td_target = data.rewards.flatten() + args.gamma * target_max * (1 - data.dones.flatten())
                old_val = q_network(data.observations).gather(1, data.actions).squeeze()
                loss = F.mse_loss(td_target, old_val)

                if global_step % 100 == 0:
                    writer.add_scalar("losses/td_loss", loss, global_step)
                    writer.add_scalar("losses/q_values", old_val.mean().item(), global_step)
                    print("SPS:", int(global_step / (time.time() - start_time)))
                    writer.add_scalar("charts/SPS", int(global_step / (time.time() - start_time)), global_step)

                # optimize the model
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()

            # update target network
            if global_step % args.target_network_frequency == 0:
                for target_network_param, q_network_param in zip(target_network.parameters(), q_network.parameters()):
                    target_network_param.data.copy_(
                        args.tau * q_network_param.data + (1.0 - args.tau) * target_network_param.data
                    )

    if args.save_model:
        model_path = f"runs/{run_name}/{args.exp_name}.cleanrl_model"
        torch.save(q_network.state_dict(), model_path)
        print(f"model saved to {model_path}")
        from cleanrl_utils.evals.dqn_eval import evaluate

        episodic_returns = evaluate(
            model_path,
            make_env,
            args.env_id,
            eval_episodes=10,
            run_name=f"{run_name}-eval",
            Model=QNetwork,
            device=device,
            epsilon=args.end_e,
        )
        for idx, episodic_return in enumerate(episodic_returns):
            writer.add_scalar("eval/episodic_return", episodic_return, idx)

        if args.upload_model:
            from cleanrl_utils.huggingface import push_to_hub

            repo_name = f"{args.env_id}-{args.exp_name}-seed{args.seed}"
            repo_id = f"{args.hf_entity}/{repo_name}" if args.hf_entity else repo_name
            push_to_hub(args, episodic_returns, repo_id, "DQN", f"runs/{run_name}", f"videos/{run_name}-eval")

    envs.close()
    writer.close()
# Out:
# A.L.E: Arcade Learning Environment (version 0.8.1+53f58b7)
# [Powered by Stella]
# /Users/shibo/Workspace/cleanrl/cleanrl_utils/buffers.py:334: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 28.24GB > 3.07GB
#   warnings.warn(
# global_step=958, episodic_return=[-20.]
# global_step=1853, episodic_return=[-21.]
# global_step=2923, episodic_return=[-20.]
# global_step=3731, episodic_return=[-21.]
# global_step=4611, episodic_return=[-21.]
# global_step=5430, episodic_return=[-21.]
# global_step=6309, episodic_return=[-21.]
# global_step=7371, episodic_return=[-18.]
# global_step=8345, episodic_return=[-19.]
# global_step=9223, episodic_return=[-21.]
# global_step=10066, episodic_return=[-21.]
# global_step=10929, episodic_return=[-21.]
# global_step=11893, episodic_return=[-20.]
# global_step=12849, episodic_return=[-20.]
# global_step=13749, episodic_return=[-20.]
# global_step=15053, episodic_return=[-17.]
# global_step=15808, episodic_return=[-21.]
# global_step=16676, episodic_return=[-21.]
# global_step=17654, episodic_return=[-19.]
# global_step=18687, episodic_return=[-19.]
# global_step=19586, episodic_return=[-20.]
# global_step=20640, episodic_return=[-21.]
# global_step=21532, episodic_return=[-20.]
# global_step=22321, episodic_return=[-21.]
# global_step=23233, episodic_return=[-20.]
# global_step=24134, episodic_return=[-21.]
# global_step=25237, episodic_return=[-18.]
# global_step=26056, episodic_return=[-21.]
# global_step=27038, episodic_return=[-21.]
# global_step=27915, episodic_return=[-21.]
# global_step=28690, episodic_return=[-21.]
# global_step=29588, episodic_return=[-21.]
# global_step=30665, episodic_return=[-20.]
# global_step=31777, episodic_return=[-20.]
# global_step=32721, episodic_return=[-20.]
# global_step=33883, episodic_return=[-19.]
# global_step=34806, episodic_return=[-20.]
# global_step=35860, episodic_return=[-21.]
# global_step=36710, episodic_return=[-21.]
# global_step=37654, episodic_return=[-21.]
# global_step=38622, episodic_return=[-20.]
# global_step=39439, episodic_return=[-21.]
# global_step=40482, episodic_return=[-20.]
# global_step=41473, episodic_return=[-21.]
# global_step=42250, episodic_return=[-21.]
# global_step=43096, episodic_return=[-21.]
# global_step=44277, episodic_return=[-19.]
# global_step=45205, episodic_return=[-20.]
# global_step=46128, episodic_return=[-20.]
# global_step=47018, episodic_return=[-21.]
# global_step=47909, episodic_return=[-21.]
# global_step=48935, episodic_return=[-21.]
# global_step=50019, episodic_return=[-19.]
# global_step=51010, episodic_return=[-20.]
# global_step=52058, episodic_return=[-20.]
# global_step=52998, episodic_return=[-21.]
# global_step=53904, episodic_return=[-21.]
# global_step=54921, episodic_return=[-20.]
# global_step=55875, episodic_return=[-21.]
# global_step=56696, episodic_return=[-21.]
# global_step=57534, episodic_return=[-21.]
# global_step=58442, episodic_return=[-20.]
# global_step=59410, episodic_return=[-21.]
# global_step=60290, episodic_return=[-21.]
# global_step=61247, episodic_return=[-20.]
# global_step=62126, episodic_return=[-21.]
# global_step=63058, episodic_return=[-21.]
# global_step=64084, episodic_return=[-21.]
# global_step=64983, episodic_return=[-20.]
# global_step=65888, episodic_return=[-21.]
# global_step=66706, episodic_return=[-21.]
# global_step=67727, episodic_return=[-21.]
# global_step=68769, episodic_return=[-21.]
# global_step=69646, episodic_return=[-21.]
# global_step=70530, episodic_return=[-21.]
# global_step=71305, episodic_return=[-21.]
# global_step=72264, episodic_return=[-21.]
# global_step=73284, episodic_return=[-20.]
# global_step=74191, episodic_return=[-21.]
# global_step=75258, episodic_return=[-20.]
# global_step=76042, episodic_return=[-21.]
# global_step=76872, episodic_return=[-20.]
# global_step=77955, episodic_return=[-18.]
# global_step=78744, episodic_return=[-21.]
# global_step=79608, episodic_return=[-20.]
# SPS: 1604
# SPS: 1562
# SPS: 1523
# SPS: 1486
# SPS: 1451
# global_step=80533, episodic_return=[-20.]
# SPS: 1417
# SPS: 1385
# SPS: 1355
# SPS: 1325
# SPS: 1297
# SPS: 1271
# SPS: 1246
# SPS: 1221
# global_step=81367, episodic_return=[-20.]
# SPS: 1198
# SPS: 1176
# SPS: 1154
# SPS: 1133
# SPS: 1114
# SPS: 1094
# SPS: 1075
# SPS: 1057
# SPS: 1040
# global_step=82210, episodic_return=[-21.]
# SPS: 1024
# SPS: 1007
# SPS: 991
# SPS: 976
# SPS: 962
# SPS: 948
# SPS: 934
# SPS: 921
# SPS: 908
# global_step=83105, episodic_return=[-20.]
# SPS: 896
# SPS: 884
# SPS: 872
# SPS: 860
# SPS: 849
# SPS: 838
# SPS: 828
# global_step=83867, episodic_return=[-21.]
# SPS: 817
# SPS: 808
# SPS: 798
# SPS: 788
# SPS: 779
# SPS: 770
# SPS: 761
# SPS: 753
# SPS: 745
# global_step=84703, episodic_return=[-20.]
# SPS: 736
# SPS: 728
# SPS: 721
# SPS: 713
# SPS: 706
# SPS: 699
# SPS: 692
# SPS: 685
# global_step=85596, episodic_return=[-21.]
# SPS: 678
# SPS: 671
# SPS: 665
# SPS: 659
# SPS: 652
# SPS: 647
# SPS: 641
# SPS: 635
# SPS: 629
# global_step=86412, episodic_return=[-21.]
# SPS: 623
# SPS: 617
# SPS: 611
# SPS: 605
# SPS: 600
# SPS: 595
# SPS: 590
# SPS: 586
# SPS: 580
# global_step=87316, episodic_return=[-20.]
# SPS: 576
# SPS: 571
# SPS: 566
# SPS: 562
# SPS: 557
# SPS: 553
# SPS: 548
# SPS: 544
# SPS: 540
# global_step=88224, episodic_return=[-21.]
# SPS: 536
# SPS: 532
# SPS: 528
# SPS: 525
# SPS: 521
# SPS: 517
# SPS: 514
# SPS: 510
# global_step=89008, episodic_return=[-21.]
# SPS: 506
# SPS: 503
# SPS: 499
# SPS: 496
# SPS: 493
# SPS: 490
# SPS: 486
# global_step=89796, episodic_return=[-21.]
# SPS: 483
# SPS: 479
# SPS: 476
# SPS: 473
# SPS: 470
# SPS: 467
# SPS: 464
# SPS: 461
# SPS: 458
# global_step=90659, episodic_return=[-20.]
# SPS: 456
# SPS: 453
# SPS: 451
# SPS: 448
# SPS: 445
# SPS: 443
# SPS: 441
# SPS: 438
# global_step=91449, episodic_return=[-21.]
# SPS: 436
# SPS: 433
# SPS: 431
# SPS: 429
# SPS: 426
# SPS: 424
# SPS: 422
# SPS: 419
# global_step=92270, episodic_return=[-21.]
# SPS: 417
# SPS: 415
# SPS: 413
# SPS: 411
# SPS: 409
# SPS: 407
# SPS: 405
# SPS: 403
# SPS: 401
# SPS: 399
# global_step=93245, episodic_return=[-21.]
# SPS: 397
# SPS: 395
# SPS: 393
# SPS: 391
# SPS: 390
# SPS: 388
# SPS: 386
# SPS: 384
# global_step=94080, episodic_return=[-20.]
# SPS: 382
# SPS: 381
# SPS: 379
# SPS: 377
# SPS: 376
# SPS: 374
# SPS: 372
# SPS: 371
# SPS: 369
# global_step=94997, episodic_return=[-20.]
# SPS: 367
# SPS: 366
# SPS: 364
# SPS: 363
# SPS: 361
# SPS: 360
# SPS: 358
# SPS: 357
# SPS: 355
# SPS: 354
# SPS: 352
# SPS: 351
# global_step=96153, episodic_return=[-19.]
# SPS: 350
# SPS: 348
# SPS: 347
# SPS: 345
# SPS: 344
# SPS: 343
# SPS: 341
# SPS: 340
# SPS: 339
# SPS: 338
# global_step=97101, episodic_return=[-20.]
# SPS: 336
# SPS: 335
# SPS: 334
# SPS: 333
# SPS: 331
# SPS: 330
# SPS: 329
# SPS: 328
# global_step=97916, episodic_return=[-21.]
# SPS: 326
# SPS: 325
# SPS: 324
# SPS: 323
# SPS: 322
# SPS: 321
# SPS: 320
# SPS: 319
# SPS: 318
# global_step=98893, episodic_return=[-19.]
# SPS: 316
# SPS: 315
# SPS: 314
# SPS: 313
# SPS: 312
# SPS: 311
# SPS: 310
# SPS: 309
# SPS: 308
# global_step=99709, episodic_return=[-21.]
# SPS: 307
# SPS: 306
# SPS: 305
# SPS: 304
# SPS: 303
# SPS: 302
# SPS: 301
# SPS: 300
# global_step=100533, episodic_return=[-21.]
# SPS: 299
# SPS: 298
# SPS: 297
# SPS: 296
# SPS: 295
# SPS: 294
# SPS: 293
# SPS: 292
# global_step=101399, episodic_return=[-20.]
# SPS: 291
# SPS: 290
# SPS: 289
# SPS: 288
# SPS: 287
# SPS: 286
# SPS: 285
# SPS: 285
# SPS: 284
# global_step=102254, episodic_return=[-20.]
# SPS: 283
# SPS: 282
# SPS: 281
# SPS: 281
# SPS: 280
# SPS: 279
# SPS: 278
# SPS: 278
# SPS: 277
# SPS: 276
# SPS: 275
# SPS: 275
# SPS: 274
# SPS: 273
# global_step=103607, episodic_return=[-18.]
# SPS: 272
# SPS: 272
# SPS: 271
# SPS: 270
# SPS: 269
# SPS: 269
# SPS: 268
# SPS: 267
# SPS: 267
# global_step=104501, episodic_return=[-20.]
# SPS: 266
# SPS: 265
# SPS: 264
# SPS: 264
# SPS: 263
# SPS: 262
# SPS: 262
# global_step=105292, episodic_return=[-21.]
# SPS: 261
# SPS: 260
# SPS: 260
# SPS: 259
# SPS: 258
# SPS: 258
# SPS: 257
# SPS: 257
# global_step=106068, episodic_return=[-21.]
# SPS: 256
# SPS: 255
# SPS: 255
# SPS: 254
# SPS: 254
# SPS: 253
# SPS: 252
# SPS: 252
# global_step=106898, episodic_return=[-20.]
# SPS: 251
# SPS: 251
# SPS: 250
# SPS: 250
# SPS: 249
# SPS: 248
# SPS: 248
# SPS: 247
# global_step=107682, episodic_return=[-21.]
# SPS: 247
# SPS: 246
# SPS: 246
# SPS: 245
# SPS: 245
# SPS: 244
# SPS: 243
# SPS: 243
# SPS: 242
# SPS: 242
# SPS: 241
# global_step=108701, episodic_return=[-20.]
# SPS: 241
# SPS: 240
# SPS: 240
# SPS: 239
# SPS: 239
# SPS: 238
# SPS: 238
# global_step=109458, episodic_return=[-21.]
# SPS: 237
# SPS: 237
# SPS: 236
# SPS: 236
# SPS: 235
# SPS: 235
# SPS: 234
# SPS: 234
# SPS: 233
# global_step=110343, episodic_return=[-20.]
# SPS: 233
# SPS: 232
# SPS: 232
# SPS: 231
# SPS: 231
# SPS: 230
# SPS: 230
# global_step=111100, episodic_return=[-21.]
# SPS: 229
# SPS: 229
# SPS: 228
# SPS: 228
# SPS: 228
# SPS: 227
# SPS: 227
# SPS: 226
# SPS: 226
# SPS: 225
# SPS: 225
# SPS: 225
# global_step=112242, episodic_return=[-19.]
# SPS: 224
# SPS: 224
# SPS: 223
# SPS: 223
# SPS: 222
# SPS: 222
# SPS: 222
# SPS: 221
# global_step=113087, episodic_return=[-21.]
# SPS: 221
# SPS: 220
# SPS: 220
# SPS: 220
# SPS: 219
# SPS: 219
# SPS: 218
# SPS: 218
# SPS: 218
# global_step=113917, episodic_return=[-21.]
# SPS: 217
# SPS: 217
# SPS: 217
# SPS: 216
# SPS: 216
# SPS: 215
# SPS: 215
# SPS: 215
# global_step=114779, episodic_return=[-20.]
# SPS: 214
# SPS: 214
# SPS: 214
# SPS: 213
# SPS: 213
# SPS: 212
# SPS: 212
# SPS: 212
# SPS: 211
# SPS: 211
# SPS: 211
# global_step=115887, episodic_return=[-21.]
# SPS: 210
# SPS: 210
# SPS: 210
# SPS: 209
# SPS: 209
# SPS: 209
# SPS: 208
# SPS: 208
# global_step=116646, episodic_return=[-21.]
# SPS: 208
# SPS: 207
# SPS: 207
# SPS: 207
# SPS: 206
# SPS: 206
# SPS: 206
# SPS: 205
# SPS: 205
# global_step=117588, episodic_return=[-20.]
# SPS: 205
# SPS: 204
# SPS: 204
# SPS: 204
# SPS: 203
# SPS: 203
# SPS: 203
# SPS: 202
# global_step=118350, episodic_return=[-21.]
# SPS: 202
# SPS: 202
# SPS: 202
# SPS: 201
# SPS: 201
# SPS: 201
# SPS: 200
# SPS: 200
# global_step=119169, episodic_return=[-21.]
# SPS: 200
# SPS: 199
# SPS: 199
# SPS: 199
# SPS: 199
# SPS: 198
# SPS: 198
# SPS: 198
# SPS: 197
# SPS: 197
# global_step=120160, episodic_return=[-20.]
# SPS: 197
# SPS: 197
# SPS: 196
# SPS: 196
# SPS: 196
# SPS: 195
# SPS: 195
# SPS: 195
# global_step=120990, episodic_return=[-20.]
# SPS: 195
# SPS: 194
# SPS: 194
# SPS: 194
# SPS: 194
# SPS: 193
# SPS: 193
# SPS: 193
# SPS: 192
# global_step=121857, episodic_return=[-20.]
# SPS: 192
# SPS: 192
# SPS: 192
# SPS: 191
# SPS: 191
# SPS: 191
# SPS: 191
# SPS: 190
# global_step=122636, episodic_return=[-21.]
# SPS: 190
# SPS: 190
# SPS: 190
# SPS: 189
# SPS: 189
# SPS: 189
# SPS: 189
# SPS: 188
# SPS: 188
# SPS: 188
# global_step=123627, episodic_return=[-20.]
# SPS: 188
# SPS: 187
# SPS: 187
# SPS: 187
# SPS: 186
# SPS: 186
# SPS: 186
# SPS: 186
# global_step=124478, episodic_return=[-21.]
# SPS: 185
# SPS: 185
# SPS: 185
# SPS: 185
# SPS: 184
# SPS: 184
# SPS: 184
# SPS: 183
# SPS: 183
# global_step=125344, episodic_return=[-21.]
# SPS: 183
# SPS: 183
# SPS: 182
# SPS: 182
# SPS: 182
# SPS: 182
# SPS: 181
# SPS: 181
# global_step=126147, episodic_return=[-21.]
# SPS: 181
# SPS: 181
# SPS: 180
# SPS: 180
# SPS: 180
# SPS: 180
# SPS: 179
# SPS: 179
# global_step=126995, episodic_return=[-21.]
# SPS: 179
# SPS: 179
# SPS: 178
# SPS: 178
# SPS: 178
# SPS: 178
# SPS: 177
# SPS: 177
# SPS: 177
# global_step=127891, episodic_return=[-20.]
# SPS: 177
# SPS: 176
# SPS: 176
# SPS: 176
# SPS: 176
# SPS: 175
# SPS: 175
# SPS: 175
# SPS: 175
# SPS: 174
# SPS: 174
# SPS: 174
# global_step=129034, episodic_return=[-19.]
# SPS: 174
# SPS: 173
# SPS: 173
# SPS: 173
# SPS: 173
# SPS: 173
# SPS: 172
# SPS: 172
# SPS: 172
# SPS: 172
# global_step=130017, episodic_return=[-20.]
# SPS: 171
# SPS: 171
# SPS: 171
# SPS: 171
# SPS: 171
# SPS: 170
# SPS: 170
# SPS: 170
# SPS: 170
# global_step=130921, episodic_return=[-21.]
# SPS: 169
# SPS: 169
# SPS: 169
# SPS: 169
# SPS: 169
# SPS: 168
# SPS: 168
# SPS: 168
# SPS: 168
# global_step=131856, episodic_return=[-19.]
# SPS: 168
# SPS: 167
# SPS: 167
# SPS: 167
# SPS: 167
# SPS: 167
# SPS: 166
# SPS: 166
# global_step=132644, episodic_return=[-21.]
# SPS: 166
# SPS: 166
# SPS: 166
# SPS: 166
# SPS: 165
# SPS: 165
# SPS: 165
# SPS: 165
# global_step=133428, episodic_return=[-21.]
# SPS: 165
# SPS: 165
# SPS: 164
# SPS: 164
# SPS: 164
# SPS: 164
# SPS: 164
# SPS: 164
# global_step=134250, episodic_return=[-21.]
# SPS: 163
# SPS: 163
# SPS: 163
# SPS: 163
# SPS: 163
# SPS: 162
# SPS: 162
# SPS: 162
# SPS: 162
# SPS: 162
# SPS: 161
# global_step=135340, episodic_return=[-18.]
# SPS: 161
# SPS: 161
# SPS: 161
# SPS: 161
# SPS: 161
# SPS: 161
# SPS: 160
# SPS: 160
# SPS: 160
# SPS: 160
# global_step=136392, episodic_return=[-19.]
# SPS: 160
# SPS: 160
# SPS: 160
# SPS: 159
# SPS: 159
# SPS: 159
# SPS: 159
# SPS: 159
# SPS: 159
# global_step=137289, episodic_return=[-21.]
# SPS: 159
# SPS: 159
# SPS: 158
# SPS: 158
# SPS: 158
# SPS: 158
# SPS: 158
# SPS: 158
# SPS: 158
# global_step=138185, episodic_return=[-21.]
# SPS: 157
# SPS: 157
# SPS: 157
# SPS: 157
# SPS: 157
# SPS: 157
# SPS: 157
# SPS: 157
# SPS: 156
# SPS: 156
# SPS: 156
# global_step=139260, episodic_return=[-18.]
# SPS: 156
# SPS: 156
# SPS: 156
# SPS: 156
# SPS: 156
# SPS: 155
# SPS: 155
# SPS: 155
# global_step=140095, episodic_return=[-20.]
# SPS: 155
# SPS: 155
# SPS: 155
# SPS: 155
# SPS: 154
# SPS: 154
# SPS: 154
# SPS: 154
# SPS: 154
# global_step=140950, episodic_return=[-21.]
# SPS: 154
# SPS: 154
# SPS: 153
# SPS: 153
# SPS: 153
# SPS: 153
# SPS: 153
# SPS: 153
# SPS: 153
# SPS: 153
# global_step=141919, episodic_return=[-21.]
# SPS: 152
# SPS: 152
# SPS: 152
# SPS: 152
# SPS: 152
# SPS: 152
# SPS: 152
# SPS: 152
# global_step=142781, episodic_return=[-20.]
# SPS: 151
# SPS: 151
# SPS: 151
# SPS: 151
# SPS: 151
# SPS: 151
# SPS: 151
# SPS: 151
# global_step=143540, episodic_return=[-21.]
# SPS: 150
# SPS: 150
# SPS: 150
# SPS: 150
# SPS: 150
# SPS: 150
# SPS: 150
# SPS: 150
# SPS: 149
# global_step=144433, episodic_return=[-20.]
# SPS: 149
# SPS: 149
# SPS: 149
# SPS: 149
# SPS: 149
# SPS: 149
# SPS: 149
# SPS: 149
# SPS: 148
# global_step=145389, episodic_return=[-21.]
# SPS: 148
# SPS: 148
# SPS: 148
# SPS: 148
# SPS: 148
# SPS: 148
# SPS: 148
# SPS: 148
# global_step=146175, episodic_return=[-21.]
# SPS: 147
# SPS: 147
# SPS: 147
# SPS: 147
# SPS: 147
# SPS: 147
# SPS: 147
# SPS: 147
# SPS: 147
# SPS: 146
# SPS: 146
# SPS: 146
# global_step=147336, episodic_return=[-19.]
# SPS: 146
# SPS: 146
# SPS: 146
# SPS: 146
# SPS: 146
# SPS: 146
# SPS: 145
# SPS: 145
# SPS: 145
# SPS: 145
# global_step=148383, episodic_return=[-18.]
# SPS: 145
# SPS: 145
# SPS: 145
# SPS: 145
# SPS: 145
# SPS: 145
# SPS: 145
# SPS: 144
# SPS: 144
# SPS: 144
# global_step=149341, episodic_return=[-20.]
# SPS: 144
# SPS: 144
# SPS: 144
# SPS: 144
# SPS: 144
# SPS: 144
# SPS: 144
# SPS: 143
# global_step=150101, episodic_return=[-21.]
# SPS: 143
# SPS: 143
# SPS: 143
# SPS: 143
# SPS: 143
# SPS: 143
# SPS: 143
# SPS: 143
# global_step=150963, episodic_return=[-20.]
# SPS: 143
# SPS: 142
# SPS: 142
# SPS: 142
# SPS: 142
# SPS: 142
# SPS: 142
# SPS: 142
# SPS: 142
# global_step=151860, episodic_return=[-21.]
# SPS: 142
# SPS: 142
# SPS: 142
# SPS: 141
# SPS: 141
# SPS: 141
# SPS: 141
# SPS: 141
# SPS: 141
# SPS: 141
# global_step=152803, episodic_return=[-20.]
# SPS: 141
# SPS: 141
# SPS: 141
# SPS: 140
# SPS: 140
# SPS: 140
# SPS: 140
# SPS: 140
# SPS: 140
# global_step=153764, episodic_return=[-20.]
# SPS: 140
# SPS: 140
# SPS: 140
# SPS: 140
# SPS: 140
# SPS: 140
# SPS: 139
# SPS: 139
# SPS: 139
# SPS: 139
# SPS: 139
# SPS: 139
# global_step=154911, episodic_return=[-18.]
# SPS: 139
# SPS: 139
# SPS: 139
# SPS: 139
# SPS: 139
# SPS: 139
# SPS: 138
# SPS: 138
# SPS: 138
# global_step=155840, episodic_return=[-20.]
# SPS: 138
# SPS: 138
# SPS: 138
# SPS: 138
# SPS: 138
# SPS: 138
# SPS: 138
# SPS: 138
# SPS: 138
# global_step=156738, episodic_return=[-20.]
# SPS: 137
# SPS: 137
# SPS: 137
# SPS: 137
# SPS: 137
# SPS: 137
# SPS: 137
# SPS: 137
# SPS: 137
# global_step=157614, episodic_return=[-21.]
# SPS: 137
# SPS: 137
# SPS: 137
# SPS: 137
# SPS: 136
# SPS: 136
# SPS: 136
# SPS: 136
# global_step=158426, episodic_return=[-21.]
# SPS: 136
# SPS: 136
# SPS: 136
# SPS: 136
# SPS: 136
# SPS: 136
# SPS: 136
# SPS: 136
# SPS: 136
# global_step=159389, episodic_return=[-21.]
# SPS: 135
# SPS: 135
# SPS: 135
# SPS: 135
# SPS: 135
# SPS: 135
# SPS: 135
# SPS: 135
# SPS: 135
# global_step=160270, episodic_return=[-20.]
# SPS: 135
# SPS: 135
# SPS: 135
# SPS: 135
# SPS: 134
# SPS: 134
# SPS: 134
# SPS: 134
# global_step=161087, episodic_return=[-21.]
# SPS: 134
# SPS: 134
# SPS: 134
# SPS: 134
# SPS: 134
# SPS: 134
# SPS: 134
# SPS: 134
# SPS: 134
# SPS: 134
# global_step=162037, episodic_return=[-20.]
# SPS: 134
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 133
# global_step=163035, episodic_return=[-19.]
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 133
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# global_step=164153, episodic_return=[-21.]
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# SPS: 132
# global_step=165038, episodic_return=[-20.]
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 131
# global_step=165995, episodic_return=[-21.]
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 131
# SPS: 130
# SPS: 130
# SPS: 130
# SPS: 130
# global_step=166845, episodic_return=[-21.]
# SPS: 130
# SPS: 130
# SPS: 130
# SPS: 130
# SPS: 130
# SPS: 130
# SPS: 130
# SPS: 130
# SPS: 130
# global_step=167742, episodic_return=[-20.]
# SPS: 130
# SPS: 130
# SPS: 130
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# global_step=168714, episodic_return=[-19.]
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# SPS: 129
# global_step=169532, episodic_return=[-21.]
# SPS: 129
# SPS: 129
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# global_step=170410, episodic_return=[-21.]
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# SPS: 128
# global_step=171446, episodic_return=[-19.]
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# global_step=172508, episodic_return=[-20.]
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 127
# SPS: 126
# SPS: 126
# SPS: 126
# global_step=173346, episodic_return=[-20.]
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 126
# global_step=174367, episodic_return=[-20.]
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 126
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# global_step=175249, episodic_return=[-20.]
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 125
# global_step=176209, episodic_return=[-20.]
# SPS: 125
# SPS: 125
# SPS: 125
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# global_step=177044, episodic_return=[-20.]
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# global_step=178038, episodic_return=[-19.]
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 124
# SPS: 123
# SPS: 123
# SPS: 123
# global_step=178855, episodic_return=[-21.]
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# global_step=179848, episodic_return=[-20.]
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 123
# SPS: 122
# SPS: 122
# global_step=180786, episodic_return=[-21.]
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# global_step=181604, episodic_return=[-21.]
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# SPS: 122
# global_step=182596, episodic_return=[-18.]
# SPS: 122
# SPS: 122
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# global_step=183664, episodic_return=[-20.]
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# global_step=184423, episodic_return=[-21.]
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 121
# SPS: 120
# SPS: 120
# SPS: 120
# global_step=185240, episodic_return=[-21.]
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# global_step=186188, episodic_return=[-20.]
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# SPS: 120
# global_step=187084, episodic_return=[-21.]
# SPS: 120
# SPS: 120
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# global_step=188012, episodic_return=[-21.]
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# global_step=188861, episodic_return=[-21.]
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 119
# SPS: 118
# global_step=189737, episodic_return=[-21.]
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# global_step=190833, episodic_return=[-19.]
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# global_step=191837, episodic_return=[-19.]
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 118
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# global_step=192720, episodic_return=[-21.]
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# global_step=193572, episodic_return=[-20.]
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 117
# global_step=194483, episodic_return=[-20.]
# SPS: 117
# SPS: 117
# SPS: 117
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# global_step=195432, episodic_return=[-20.]
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# global_step=196344, episodic_return=[-20.]
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 116
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# global_step=197673, episodic_return=[-18.]
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# global_step=198520, episodic_return=[-21.]
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# global_step=199392, episodic_return=[-21.]
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 115
# SPS: 114
# global_step=200181, episodic_return=[-21.]
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# global_step=201062, episodic_return=[-21.]
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# global_step=201946, episodic_return=[-20.]
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# SPS: 114
# global_step=202926, episodic_return=[-19.]
# SPS: 114
# SPS: 114
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# global_step=204034, episodic_return=[-18.]
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# global_step=204945, episodic_return=[-19.]
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# global_step=205765, episodic_return=[-21.]
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 113
# SPS: 112
# SPS: 112
# SPS: 112
# global_step=206549, episodic_return=[-21.]
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# global_step=207388, episodic_return=[-21.]
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# global_step=208334, episodic_return=[-20.]
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 112
# global_step=209265, episodic_return=[-19.]
# SPS: 112
# SPS: 112
# SPS: 112
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# global_step=210193, episodic_return=[-20.]
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# global_step=211011, episodic_return=[-21.]
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# global_step=211861, episodic_return=[-21.]
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# SPS: 111
# global_step=212851, episodic_return=[-20.]
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# global_step=213868, episodic_return=[-20.]
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# global_step=214707, episodic_return=[-20.]
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# global_step=215540, episodic_return=[-20.]
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# SPS: 110
# global_step=216416, episodic_return=[-21.]
# SPS: 110
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# global_step=217265, episodic_return=[-20.]
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# global_step=218104, episodic_return=[-21.]
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# global_step=219094, episodic_return=[-20.]
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# global_step=219986, episodic_return=[-20.]
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 109
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# global_step=220802, episodic_return=[-21.]
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# global_step=221623, episodic_return=[-21.]
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# global_step=222615, episodic_return=[-19.]
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# global_step=223816, episodic_return=[-19.]
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 108
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# global_step=224730, episodic_return=[-19.]
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# global_step=225626, episodic_return=[-20.]
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# global_step=226476, episodic_return=[-21.]
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# global_step=227598, episodic_return=[-19.]
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# SPS: 107
# global_step=228577, episodic_return=[-20.]
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# global_step=229611, episodic_return=[-19.]
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# global_step=230426, episodic_return=[-21.]
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# global_step=231300, episodic_return=[-21.]
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# global_step=232060, episodic_return=[-21.]
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 106
# SPS: 105
# global_step=233116, episodic_return=[-19.]
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# global_step=234032, episodic_return=[-20.]
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# global_step=234789, episodic_return=[-21.]
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# global_step=235565, episodic_return=[-21.]
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# global_step=236369, episodic_return=[-21.]
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# global_step=237228, episodic_return=[-21.]
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 105
# SPS: 104
# SPS: 104
# SPS: 104
# global_step=238073, episodic_return=[-21.]
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# global_step=238953, episodic_return=[-21.]
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# global_step=239885, episodic_return=[-20.]
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# global_step=240747, episodic_return=[-20.]
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# global_step=241674, episodic_return=[-21.]
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# SPS: 104
# global_step=242458, episodic_return=[-21.]
# SPS: 104
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# global_step=243326, episodic_return=[-20.]
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# global_step=244363, episodic_return=[-20.]
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# global_step=245235, episodic_return=[-21.]
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# global_step=245996, episodic_return=[-21.]
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# global_step=246834, episodic_return=[-20.]
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# SPS: 103
# global_step=247614, episodic_return=[-21.]
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# global_step=248422, episodic_return=[-21.]
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# global_step=249285, episodic_return=[-21.]
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# global_step=250102, episodic_return=[-21.]
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# global_step=251077, episodic_return=[-20.]
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# global_step=252040, episodic_return=[-20.]
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# global_step=252897, episodic_return=[-20.]
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 102
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# global_step=253835, episodic_return=[-21.]
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# global_step=254663, episodic_return=[-20.]
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# global_step=255736, episodic_return=[-19.]
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# global_step=256655, episodic_return=[-21.]
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# global_step=257655, episodic_return=[-21.]
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# global_step=258640, episodic_return=[-20.]
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# SPS: 101
# global_step=259536, episodic_return=[-21.]
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# global_step=260495, episodic_return=[-19.]
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# global_step=261422, episodic_return=[-20.]
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# global_step=262318, episodic_return=[-21.]
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# global_step=263186, episodic_return=[-21.]
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# global_step=264129, episodic_return=[-19.]
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# global_step=264932, episodic_return=[-21.]
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# SPS: 100
# global_step=265710, episodic_return=[-21.]
# SPS: 100
# SPS: 100
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# global_step=266569, episodic_return=[-20.]
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# global_step=267432, episodic_return=[-20.]
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# global_step=268309, episodic_return=[-21.]
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# global_step=269149, episodic_return=[-21.]
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# global_step=270093, episodic_return=[-20.]
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# global_step=270989, episodic_return=[-21.]
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# global_step=271851, episodic_return=[-21.]
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# SPS: 99
# global_step=272811, episodic_return=[-20.]
# SPS: 99
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# global_step=273676, episodic_return=[-21.]
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# global_step=274603, episodic_return=[-20.]
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# global_step=275556, episodic_return=[-20.]
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# global_step=276314, episodic_return=[-21.]
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# global_step=277133, episodic_return=[-21.]
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# global_step=278042, episodic_return=[-21.]
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# global_step=278859, episodic_return=[-21.]
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# global_step=279759, episodic_return=[-20.]
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 98
# SPS: 97
# global_step=280610, episodic_return=[-21.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# global_step=281574, episodic_return=[-19.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# global_step=282329, episodic_return=[-21.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# global_step=283091, episodic_return=[-21.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# global_step=283951, episodic_return=[-20.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# global_step=284849, episodic_return=[-20.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# global_step=285789, episodic_return=[-19.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# global_step=286789, episodic_return=[-19.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# global_step=287693, episodic_return=[-21.]
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 97
# SPS: 96
# global_step=288593, episodic_return=[-20.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=289430, episodic_return=[-21.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=290251, episodic_return=[-21.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=291109, episodic_return=[-20.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=291991, episodic_return=[-21.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=292931, episodic_return=[-20.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=293749, episodic_return=[-21.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=294777, episodic_return=[-18.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=295659, episodic_return=[-21.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# global_step=296799, episodic_return=[-17.]
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 96
# SPS: 95
# SPS: 95
# global_step=297636, episodic_return=[-20.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=298736, episodic_return=[-19.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=299698, episodic_return=[-19.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=300691, episodic_return=[-19.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=301525, episodic_return=[-20.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=302469, episodic_return=[-19.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=303347, episodic_return=[-20.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=304196, episodic_return=[-21.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=305227, episodic_return=[-20.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=306160, episodic_return=[-21.]
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# SPS: 95
# global_step=306979, episodic_return=[-21.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=307799, episodic_return=[-21.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=308622, episodic_return=[-21.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=309501, episodic_return=[-20.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=310487, episodic_return=[-19.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=311508, episodic_return=[-20.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=312344, episodic_return=[-21.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=313486, episodic_return=[-18.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=314631, episodic_return=[-18.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=315449, episodic_return=[-21.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=316315, episodic_return=[-20.]
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# SPS: 94
# global_step=317328, episodic_return=[-19.]
# SPS: 94
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=318088, episodic_return=[-21.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=319039, episodic_return=[-20.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=319818, episodic_return=[-21.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=320813, episodic_return=[-19.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=321662, episodic_return=[-21.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=322496, episodic_return=[-20.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=323299, episodic_return=[-21.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=324084, episodic_return=[-21.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=324959, episodic_return=[-21.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=325853, episodic_return=[-20.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=326670, episodic_return=[-21.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=327708, episodic_return=[-18.]
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# SPS: 93
# global_step=328619, episodic_return=[-20.]
# SPS: 93
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=329375, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=330362, episodic_return=[-19.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=331360, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=332207, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=333090, episodic_return=[-20.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=333947, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=334869, episodic_return=[-20.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=335804, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=336565, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=337325, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=338230, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=339068, episodic_return=[-20.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=339908, episodic_return=[-20.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# global_step=340716, episodic_return=[-21.]
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 92
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=341718, episodic_return=[-20.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=342594, episodic_return=[-21.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=343488, episodic_return=[-20.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=344276, episodic_return=[-21.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=345366, episodic_return=[-20.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=346286, episodic_return=[-20.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=347239, episodic_return=[-20.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=348148, episodic_return=[-19.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=349200, episodic_return=[-18.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=350033, episodic_return=[-21.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=351319, episodic_return=[-19.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=352275, episodic_return=[-20.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=353107, episodic_return=[-21.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# global_step=353971, episodic_return=[-21.]
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 91
# SPS: 90
# SPS: 90
# global_step=354986, episodic_return=[-19.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=355863, episodic_return=[-21.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=356818, episodic_return=[-20.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=357607, episodic_return=[-21.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=358645, episodic_return=[-19.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=359525, episodic_return=[-21.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=360407, episodic_return=[-21.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=361219, episodic_return=[-21.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=362053, episodic_return=[-21.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=362891, episodic_return=[-20.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=363789, episodic_return=[-20.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=364627, episodic_return=[-20.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=365521, episodic_return=[-21.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=366278, episodic_return=[-21.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=367111, episodic_return=[-20.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=368007, episodic_return=[-20.]
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# SPS: 90
# global_step=368906, episodic_return=[-20.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=369891, episodic_return=[-21.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=371111, episodic_return=[-20.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=371890, episodic_return=[-21.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=372666, episodic_return=[-21.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=373512, episodic_return=[-21.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=374332, episodic_return=[-21.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=375462, episodic_return=[-18.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=376352, episodic_return=[-20.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=377172, episodic_return=[-21.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=378010, episodic_return=[-20.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=378912, episodic_return=[-21.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=379692, episodic_return=[-21.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=380667, episodic_return=[-20.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=381532, episodic_return=[-20.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# global_step=382368, episodic_return=[-20.]
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 89
# SPS: 88
# SPS: 88
# SPS: 88
# global_step=383432, episodic_return=[-19.]
# SPS: 88
# SPS: 88
# SPS: 88
# SPS: 88
# SPS: 88
# SPS: 88
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 225
#     223 data = rb.sample(args.batch_size)
#     224 with torch.no_grad():
# --> 225     target_max, _ = target_network(data.next_observations).max(dim=1)
#     226     td_target = data.rewards.flatten() + args.gamma * target_max * (1 - data.dones.flatten())
#     227 old_val = q_network(data.observations).gather(1, data.actions).squeeze()
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# Cell In[2], line 126, in QNetwork.forward(self, x)
#     125 def forward(self, x):
# --> 126     return self.network(x / 255.0)
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/container.py:219, in Sequential.forward(self, input)
#     217 def forward(self, input):
#     218     for module in self:
# --> 219         input = module(input)
#     220     return input
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/conv.py:458, in Conv2d.forward(self, input)
#     457 def forward(self, input: Tensor) -> Tensor:
# --> 458     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/Workspace/cleanrl/.venv/lib/python3.9/site-packages/torch/nn/modules/conv.py:454, in Conv2d._conv_forward(self, input, weight, bias)
#     450 if self.padding_mode != 'zeros':
#     451     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     452                     weight, bias, self.stride,
#     453                     _pair(0), self.dilation, self.groups)
# --> 454 return F.conv2d(input, weight, bias, self.stride,
#     455                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:
